# %% [markdown]
# <a href="https://colab.research.google.com/github/adebolarahman17/Boxes/blob/main/Copy_of_Welcome_to_Colaboratory.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <h1>Welcome to Colab!</h1>
#
# If you're already familiar with Colab, check out this video to learn about interactive tables, the executed code history view and the command palette.
#
# <center>
#   <a href="https://www.youtube.com/watch?v=rNgswRZ2C1Y" target="_blank">
#   <img alt='Thumbnail for a video showing three cool Google Colab features' src="data:image/png;base64,..." height="188" width="336">
#   </a>
# </center>

# %%
import pandas as pd
import tweepy

# %%
auth = tweepy.OAuthHandler("p6xFT6q6fE7JdGHrkAqJpBWXn","FAdEO9zTwSgVbX40AM42plFtxWJZXSPqviUPj5CeMgMRq0FSoA")
auth.set_access_token("391841745-UnYNIviEzqfBXEGxwwuVsFdxoRqglXR97yGiO75g","YN1m9XMYamhcOvvh0CySvuFU2ec1ctYDAzVqcnV3NpNHf")
api=tweepy.API(auth,wait_on_rate_limit=True)

# %%
from tweepy import cursor
cursor=tweepy.Cursor(api.user_timeline,id='asakemusik',tweet_mode='extended').items(1)

# %%
for i in cursor:
    print(i.full_text)
# Out:
# RT @asakemusik: “OMO OPE” #1 in 🇳🇬❤️
# .
# #OLOLADE #YBNL https://t.co/4PK2EE1mJY

# %%
tweets = tweepy.Cursor(api.search,
              q='covid',
              lang="en",
              since='2020-01-01',
              ).items(1000)

# %%
for tweet in (tweets):
    print(tweet.text)
# Out:
# RT @himantabiswa: By developing &amp; manufacturing Covid vaccines, India proved its mettle to the world. It also shows that when Adarniya PM S…
# RT @RichardKNaidu: The economy has crashed 24%, the West is recovering from floods, tens of thousands remain jobless after Covid - and what…
# RT @DrEricDing: 🧬Wow—REAWAKENING ancient virus remnants in human DNA—new study finds #SARSCoV2 “can induce (dormant) HERV-W ENV expression”…
# RT @cccammy1: Can someone explain why people in Berwick who don't have face masks are not dying of Covid, but 3 miles away in Scotland, mas…
# 71-year-old Girija was unsure about COVID-19 vaccines. Till volunteers from the largest vaccine awareness drive,… https://t.co/spiDosnazS
# RT @Kit_Yates_Maths: The government's own coronavirus rules say an individual must isolate "straight away" if they record a positive latera…
# Wordle 235 4/6
#
# We recovering from covid iktr
#
# 🟨⬛⬛⬛🟨
# 🟩🟨🟨⬛⬛
# 🟩⬛⬛🟨🟨
# 🟩🟩🟩🟩🟩
# RT @elleprovocateur: Yesterday's #ID2020 is today's Good Health Pass, is tomorrows Digital Identity for All.
#
# #Freedom-As-A-Service
#
# The co…
# @Barking_Digits @LittleMissMaryB I’ve never caught heart disease games night with my friend!
#
# However, I have caug… https://t.co/O6PKeOr7gU
# RT @BWCHBoss: A true pleasure to welcome ⁦@Emily_JR_Lawson⁩ to Birmingham and Solihull today to share the highs, lows and lessons from our…
# @SaveTheNHS4U @GraceNoted @StaveleyMWFCNo1 @JohnDalton6011 Yet 170 000 have died from Covid. Thatcher KNIGHTED savi… https://t.co/OvlMCC1cGR
# WHO urges rich countries to pay up for Covid plan https://t.co/aCu56MCkGH
# RT @willis_macp: Joe Clarke is among England's (non-travelling) Covid/injury reserves for the tour of the West Indies next month https://t.…
# RT @MattGubba: To anyone wondering why there would be a sudden push for HIV tests... the answer is simple.
#
# As testing for covid tails off…
# RT @VirusesImmunity: Nasal Spray Booster Keeps COVID-19 at Bay - an excellent piece by Meghan Rosen.
#
# So grateful to @HHMINEWS for stepping…
T @ErrolWebber: Pfizer reported $36,800,000,000 in COVID vaccine sales in 2021.
#
# Just Pfizer.
#
# It is now their top selling product — and t…
# RT @RWoodwa31597327: @LBC @NickFerrariLBC Good grief. Nick thinks it's okay to spread covid in a humanitarian way.
#
# How do @LBC staff feel…
# RT @jennybethm: BREAKING: Biden’s DHS has declared a heightened terrorism threat due to “misinformation” and “conspiracy theories” regardin…
# RT @LeyshaSenyum: my husband has had to go into the office these past two days. today he got a notification that someone in his office is C…
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     376             try:  # Python 2.7, use buffering of HTTP responses
# --> 377                 httplib_response = conn.getresponse(buffering=True)
#     378             except TypeError:  # Python 3
#
# TypeError: getresponse() got an unexpected keyword argument 'buffering'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-15-875b5f523c03> in <module>()
# ----> 1 for tweet in (tweets):
#       2     print(tweet.text)
#
# /usr/local/lib/python3.7/dist-packages/tweepy/cursor.py in __next__(self)
#      49
#      50     def __next__(self):
# ---> 51         return self.next()
#      52
#      53     def next(self):
#
# /usr/local/lib/python3.7/dist-packages/tweepy/cursor.py in next(self)
#     241         if self.current_page is None or self.page_index == len(self.current_page) - 1:
#     242             # Reached end of current page, get the next page...
# --> 243             self.current_page = self.page_iterator.next()
#     244             while len(self.current_page) == 0:
#     245                 self.current_page = self.page_iterator.next()
#
# /usr/local/lib/python3.7/dist-packages/tweepy/cursor.py in next(self)
#     130
#     131         if self.index >= len(self.results) - 1:
# --> 132             data = self.method(max_id=self.max_id, parser=RawParser(), *self.args, **self.kwargs)
#     133
#     134             if hasattr(self.method, '__self__'):
#
# /usr/local/lib/python3.7/dist-packages/tweepy/binder.py in _call(*args, **kwargs)
#     251                 return method
#     252             else:
# --> 253                 return method.execute()
#     254         finally:
#     255             method.session.close()
#
# /usr/local/lib/python3.7/dist-packages/tweepy/binder.py in execute(self)
#     188                                                 timeout=self.api.timeout,
#     189                                                 auth=auth,
# --> 190                                                 proxies=self.api.proxy)
#     191                 except Exception as e:
#     192                     six.reraise(TweepError, TweepError('Failed to send request: %s' % e), sys.exc_info()[2])
#
# /usr/local/lib/python3.7/dist-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     528         }
#     529         send_kwargs.update(settings)
# --> 530         resp = self.send(prep, **send_kwargs)
#     531
#     532         return resp
#
# /usr/local/lib/python3.7/dist-packages/requests/sessions.py in send(self, request, **kwargs)
#     641
#     642         # Send the request
# --> 643         r = adapter.send(request, **kwargs)
#     644
#     645         # Total elapsed time of the request (approximately)
#
# /usr/local/lib/python3.7/dist-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     447                     decode_content=False,
#     448                     retries=self.max_retries,
# --> 449                     timeout=timeout
#     450                 )
#     451
#
# /usr/local/lib/python3.7/dist-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     598                                                   timeout=timeout_obj,
#     599                                                   body=body, headers=headers,
# --> 600                                                   chunked=chunked)
#     601
#     602             # If we're going to release the connection in ``finally:``, then
#
# /usr/local/lib/python3.7/dist-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     378             except TypeError:  # Python 3
#     379                 try:
# --> 380                     httplib_response = conn.getresponse()
#     381                 except Exception as e:
#     382                     # Remove the TypeError from the exception chain in Python 3;
#
# /usr/lib/python3.7/http/client.py in getresponse(self)
#    1371         try:
#    1372             try:
# -> 1373                 response.begin()
#    1374             except ConnectionError:
#    1375                 self.close()
#
# /usr/lib/python3.7/http/client.py in begin(self)
#     317         # read until we get a non-100 response
#     318         while True:
# --> 319             version, status, reason = self._read_status()
#     320             if status != CONTINUE:
#     321                 break
#
# /usr/lib/python3.7/http/client.py in _read_status(self)
#     278
#     279     def _read_status(self):
# --> 280         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     281         if len(line) > _MAXLINE:
#     282             raise LineTooLong("status line")
#
# /usr/lib/python3.7/socket.py in readinto(self, b)
#     587         while True:
#     588             try:
# --> 589                 return self._sock.recv_into(b)
#     590             except timeout:
#     591                 self._timeout_occurred = True
#
# /usr/lib/python3.7/ssl.py in recv_into(self, buffer, nbytes, flags)
#    1069                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1070                   self.__class__)
# -> 1071             return self.read(nbytes, buffer)
#    1072         else:
#    1073             return super().recv_into(buffer, nbytes, flags)
#
# /usr/lib/python3.7/ssl.py in read(self, len, buffer)
#     927         try:
#     928             if buffer is not None:
# --> 929                 return self._sslobj.read(len, buffer)
#     930             else:
#     931                 return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
users_locs = [[tweet.user.screen_name,tweet.text, tweet.created_at, tweet.user.location] for tweet in tweets]
users_locs
# Out:
# [['notshre',
#   '@amerkapur1 @anilvijminister @chkanwarpal agreed bro @amerkapur1 these r very difficult times for families who’s me… https://t.co/17lfbGZ51i',
#   datetime.datetime(2022, 2, 9, 10, 17, 51),
#   ''],
#  ['WaddeyAli',
#   'RT @qatarairways: #QatarAirways puts the health and safety of its passengers first, which is why we have implemented strict COVID-19 protoc…',
#   datetime.datetime(2022, 2, 9, 10, 17, 51),
#   'Maldives'],
#  ['M_Haynes01',
#   'RT @Haggis_UK: Susanna Reid - Gillian Keegan has apologised for continuing with an in-person meeting despite being told she had tested posi…',
#   datetime.datetime(2022, 2, 9, 10, 17, 51),
#   ''],
#  ['sachinsaraf09',
#   "RT @KiritSomaiya: Uddhav Thackeray BLACK LISTED \n\nSujeet Patkar's (Sanjay Raut Family's Partner)\n\nLifeline Hospital Management Services at…",
#   datetime.datetime(2022, 2, 9, 10, 17, 50),
#   'Earth'],
#  ['SparkleCat45',
#   'Sent this today https://t.co/LWDZXWDpni\n\nMaybe finally a step in the right direction? #LongCovid #researchneeded #helpplease',
#   datetime.datetime(2022, 2, 9, 10, 17, 50),
#   'Hertfordshire'],
#  ['khairelladam',
#   'RT @staronline: Covid-19: As cases and close contact traces rise, Sabah consumers find it hard to get self-test kits\nhttps://t.co/DI6unFfvs…',
#   datetime.datetime(2022, 2, 9, 10, 17, 50),
#   ''],
#  ['JayneCallagha10',
#   'RT @BBCPolitics: Health Minister Gillian Keegan apologises for continuing a meeting with bereaved fathers, despite discovering she had test…',
#   datetime.datetime(2022, 2, 9, 10, 17, 50),
#   'Cornwall'],
#  ['BoopHawke',
#   'RT @Kit_Yates_Maths: The government\'s own coronavirus rules say an individual must isolate "straight away" if they record a positive latera…',
#   datetime.datetime(2022, 2, 9, 10, 17, 50),
#   'East Midlands, England'],
#  ['profmath56',
#   '@Ellove1E @DonaldJTrumpJr I got the COVID vaccination as soon as I was able to. Just like I get a flu vaccine every… https://t.co/69eyGQze6a',
#   datetime.datetime(2022, 2, 9, 10, 17, 49),
#   ''],
#  ['Seju2Me',
#   "RT @_sejeongdays: [INFO] A Business Proposal's first broadcast will be on February 28, 2022 because of filming changes due to COVID-19 and…",
#   datetime.datetime(2022, 2, 9, 10, 17, 49),
#   ''],
#  ['DSTejran',
#   'RT @PeepingMoon: #EktaKapoor talks about the #pandemic theme in #Naagin6, refutes the claims of #TejasswiPrakash winning #BiggBoss15 becaus…',
#   datetime.datetime(2022, 2, 9, 10, 17, 49),
#   'INDIA'],
#  ['Kala_pasa12',
#   '@CryptoRushNetw1 @DecentDatabase This is my important question,,\nCOVID 19 has slowed down many economies around the… https://t.co/jXWbWtYNK8',
#   datetime.datetime(2022, 2, 9, 10, 17, 49),
#   ''],
#  ['Verulam6thForm',
#   'RT @stephenbase67: Up, Up and Away ✈️ Day 1 #VSocSci Y13 NYC Trip. Post Covid, empty terminal but bizarrely full flight 🤷 @Verulam6thForm h…',
#   datetime.datetime(2022, 2, 9, 10, 17, 49),
#   ''],
#  ['OmarFar09444643',
#   'RT @Tarmizi_Muji: Ulama. This message is especially for you, If you ignore it Prophet Muhammadﷺ &amp; Prophet Yusuf Alaihissalam is very concer…',
#   datetime.datetime(2022, 2, 9, 10, 17, 49),
#   ''],
#  ['robers_x',
#   'RT @sailorrooscout: Them: Tell that to Israel. They’re the most vaccinated country in the world and proof the COVID-19 vaccines don’t work.…',
#   datetime.datetime(2022, 2, 9, 10, 17, 48),
#   ''],
#  ['RoyalFamily_Fan',
#   'RT @ImperialJPNfan: Princess Yoko hospitalized in 1st COVID case for Japan imperial family - The Mainichi https://t.co/6c85yPVPxU',
#   datetime.datetime(2022, 2, 9, 10, 17, 48),
#   'Polska'],
#  ['Raymoz501',
#   'RT @ChuckCallesto: BREAKING REPORT: Freedom Convoy Organizers DOUBLE DOWN on Demands for a “PERMANENT” END to ALL Covid Mandates, Have Vowe…',
#   datetime.datetime(2022, 2, 9, 10, 17, 48),
#   '💥LOOK👀OUTSIDE YOUR WINDOW💥'],
#  ['shava23',
#   "RT @PeterHotez: Houston's Dr. Peter Hotez honored by American Medical Association for COVID work \u2066@HoustonChron\u2069 \u2066@andrewdansby\u2069  https://t…",
#   datetime.datetime(2022, 2, 9, 10, 17, 48),
#   'Fremont, CA'],
#  ['dr_raddatz',
#   'RT @GillianMcKeith: We warned everybody ....We tried our best but some people just refused to hear us....Instead, we were censored, ridicul…',
#   datetime.datetime(2022, 2, 9, 10, 17, 47),
#   'BW, Bayern, Portugal'],
#  ['MaY_KaY6',
#   'RT @VOICE_of_KNUST: 📍📍\n The current level 400s are the same batch of students whose BECE [2015] and WASSCE [2018] got canceled and replaced…',
#   datetime.datetime(2022, 2, 9, 10, 17, 46),
#   'Ghana, Western Region,Takoradi'],
#  ['DiScott9',
#   'RT @reignitedemaust: ATTENTION CANBERRA!!!\n\nSHARE SHARE SHARE\n\nThe Application for the Injunction on the roll-out of the COVID-19 vaccine o…',
#   datetime.datetime(2022, 2, 9, 10, 17, 46),
#   ''],
#  ['cathsophi',
#   'RT @zerohedge: Bill Gates Believes "Acute Phase" Of Pandemic Will Finally End In 2022 https://t.co/RPORADjal9',
#   datetime.datetime(2022, 2, 9, 10, 17, 45),
#   'Ancient Greece'],
#  ['RyanCarter7777',
#   'RT @libsoftiktok: This woman took her podcast off Spotify cuz she’s obviously very worried about Covid misinformation and health. https://t…',
#   datetime.datetime(2022, 2, 9, 10, 17, 45),
#   'Winston-Salem, NC'],
#  ['SueYeap',
#   '@Troiboi Four restaurants I follow have announced closures, temporary or otherwise, since the weekend. Others have… https://t.co/pWVTBlQGoN',
#   datetime.datetime(2022, 2, 9, 10, 17, 45),
#   'Australia'],
#  ['Thariax',
#   'RT @l_haddad: Article on efforts in Pakistan to secure good nutrition during COVID-19 crisis. Mentions great work by \u2066@GAINalliance\u2069 Pakist…',
#   datetime.datetime(2022, 2, 9, 10, 17, 45),
#   'Switzerland'],
#  ['chandaliAITC',
#   'RT @NilanjanDasAITC: The @BengalSFI staged the agitation (throwing Covid protocols to the winds)\n only to celebrate imaginary victory with…',
#   datetime.datetime(2022, 2, 9, 10, 17, 45),
#   'Chopra Assembly'],
#  ['OudeLady',
#   'RT @BHheadlines: 🔥🔥𝗕𝗥𝗘𝗔𝗞𝗜𝗡𝗚⎜ Health Minister Has Apologised For Attending Meeting After Positive Covid Test: Health minister Gillian Keegan…',
#   datetime.datetime(2022, 2, 9, 10, 17, 45),
#   ''],
#  ['avinashnazareth',
#   'RT @bainjal: First Modi blamed poor Dr Harshvardhan for Covid mishandling &amp; sacked him. Now he blames the congress. The buck never stops wi…',
#   datetime.datetime(2022, 2, 9, 10, 17, 44),
#   'Hyderabad, India'],
#  ['cshudelston',
#   'RT @ErrolWebber: Pfizer reported $36,800,000,000 in COVID vaccine sales in 2021.\n\nJust Pfizer.\n\nIt is now their top selling product — and t…',
#   datetime.datetime(2022, 2, 9, 10, 17, 43),
#   "Coeur d'Alene, ID"],
#  ['KarenJBateson',
#   'RT @NSPCCLearning: Only a third of children experiencing mental health problems accessed support during the COVID-19 pandemic, according to…',
#   datetime.datetime(2022, 2, 9, 10, 17, 43),
#   'Warwickshire. All views my own'],
#  ['Lyndacakebaker',
#   '@TheTraffic_ Oh Matey….. sorry to hear you have The Covid, hope you are feeling ok. If you were nearer would have d… https://t.co/ONSmJep0uT',
#   datetime.datetime(2022, 2, 9, 10, 17, 43),
#   'Aberfeldy'],
#  ['TourGuideTed',
#   '@chomper_TC @MrFHBear Our general rubbish &amp; recycling bins are every week, green/garden waste for about 6 months of… https://t.co/MBm3S7iWaz',
#   datetime.datetime(2022, 2, 9, 10, 17, 43),
#   'UK'],
#  ['DianneBancroft',
#   'RT @splootman: Gillian Keegan ,health minister, now apologising after testing positive for Covid during a meeting but keeping it secret and…',
#   datetime.datetime(2022, 2, 9, 10, 17, 43),
#   'Wales, United Kingdom'],
#  ['AndreaDan',
#   'New Tumblr post: "Covid-19 infects 400 million: how to deal with the virus" https://t.co/wu4EoecFqA Revyuh',
#   datetime.datetime(2022, 2, 9, 10, 17, 42),
#   'New Delhi, India'],
#  ['KedziorCarmen',
#   'RT @EpochTimes: 3 US military doctor whistleblowers say they saw DoD documents showing “skyrocketing rates of disease” since the introducti…',
#   datetime.datetime(2022, 2, 9, 10, 17, 42),
#   ''],
#  ['5h4k35p34r31',
#   '@GBNEWS Some misinformation there: the UK is spending more as a State due to Covid, not leaving the EU. Relaxing su… https://t.co/Jjf185DYzi',
#   datetime.datetime(2022, 2, 9, 10, 17, 42),
#   ''],
#  ['WendysWorld8',
#   "RT @profmiketoole: My partner's father died today of *mild* Covid-19 in Cairo. Yes, he had type 2 diabetes but it was well controlled until…",
#   datetime.datetime(2022, 2, 9, 10, 17, 42),
#   'Mallacoota, Victoria'],
#  ['jaycric',
#   "RT @kaushikcbasu: Here's IMF growth data for 2020. All nations slowed, thanks to COVID. None can be blamed for that. The question is: By ho…",
#   datetime.datetime(2022, 2, 9, 10, 17, 42),
#   'India'],
#  ['Borukusan',
#   'RT @FTM_eu: How will the hundreds of billions in the EU Covid-19 recovery fund be spent? Brussels refuses to share records about it, despit…',
#   datetime.datetime(2022, 2, 9, 10, 17, 42),
#   ''],
#  ['lahaseyogesh',
#   "RT @mvmeet: What's the greatest achievement of Yogi ji?\n\nDuring COVID lockdown, migrant workers were chased away from non-BJP ruled states…",
#   datetime.datetime(2022, 2, 9, 10, 17, 42),
#   'Buldhana, Maharashtra'],
#  ['regggaemylitis',
#   'RT @libsoftiktok: This woman took her podcast off Spotify cuz she’s obviously very worried about Covid misinformation and health. https://t…',
#   datetime.datetime(2022, 2, 9, 10, 17, 42),
#   'Mars'],
#  ['glenmexted',
#   'RT @OccupyDemocrats: BREAKING: Fox News\' Greg Gutfeld will put on a week-long series of shows in Texas that will require all attendees to "…',
#   datetime.datetime(2022, 2, 9, 10, 17, 40),
#   'london'],
#  ['STEELinNY',
#   'RT @BabeTruth2: She has died of COVID. I will NEVER UNDERSTAND this. https://t.co/GlBsJWwzd3',
#   datetime.datetime(2022, 2, 9, 10, 17, 40),
#   'Queens, NY '],
#  ['_Gattopardo',
#   'RT @mdccclxx: TL;DR\n1.Moderna is an $80billion company with a "God complex" (in the literal sense) that, prior to its COVID mRNA vaccine, h…',
#   datetime.datetime(2022, 2, 9, 10, 17, 40),
#   "Brandon, Let's Go"],
#  ['ChanSukLeng1',
#   'RT @KKMPutrajaya: Isolation Period for COVID-19 Cases and Quarantine Period for Close Contacts According To COVID-19 Vaccination Status, ef…',
#   datetime.datetime(2022, 2, 9, 10, 17, 40),
#   ''],
#  ['Sir_Farticus',
#   'RT @libsoftiktok: This woman took her podcast off Spotify cuz she’s obviously very worried about Covid misinformation and health. https://t…',
#   datetime.datetime(2022, 2, 9, 10, 17, 40),
#   'Fartingham, New Breakwind'],
#  ['Mivi1888',
#   'RT @PippaCrerar: Health minister broke letter and spirit of Covid rules - but noteworthy that she admits it, apologises, and does so quickl…',
#   datetime.datetime(2022, 2, 9, 10, 17, 39),
#   ''],
#  ['simeonlatham',
#   '@stevenmarkryan Entertaining and hopeful, hopeful that the rent seeking leeches in government are exposed to the ma… https://t.co/mioy4xzMne',
#   datetime.datetime(2022, 2, 9, 10, 17, 39),
#   'Wigan'],
#  ['Fleck05687733',
#   'RT @BlakeMMurdoch: Do people not realize that if we invest in ventilation and filtration we are helping to mitigate not only COVID and all…',
#   datetime.datetime(2022, 2, 9, 10, 17, 39),
#   ''],
#  ['AmericanDad2017',
#   'RT @ChuckCallesto: BREAKING REPORT: Freedom Convoy Organizers DOUBLE DOWN on Demands for a “PERMANENT” END to ALL Covid Mandates, Have Vowe…',
#   datetime.datetime(2022, 2, 9, 10, 17, 39),
#   'Maryland, USA'],
#  ['WalesNewsonlin1',
#   'Latest Covid figures for Hywel Dda UHBThere have been 141 new cases of Covid-19 recorded in the Hywel Dda health bo… https://t.co/wFBEPEX7fk',
#   datetime.datetime(2022, 2, 9, 10, 17, 38),
#   'Gwendraeth Valley'],
#  ['amerkapur1',
#   'RT @amerkapur1: .@anilvijminister @chkanwarpal  I would like to request you to kindly make Haryana Exams online due to the rise in covid ca…',
#   datetime.datetime(2022, 2, 9, 10, 17, 38),
#   ''],
#  ['newbeginning05',
#   'RT @talkRADIO: With the NHS backlog set to rise to 10 million patients waiting for treatment, Conservative MP Peter Bone blames "Covid rest…',
#   datetime.datetime(2022, 2, 9, 10, 17, 38),
#   ''],
#  ['AcerboLivio',
#   'France ski holidays: Discovering what the slopes are like in the age of Covid – Daily Mail on… https://t.co/u4MWQgOW7e',
#   datetime.datetime(2022, 2, 9, 10, 17, 38),
#   'Nice, France'],
#  ['davecoopcourier',
#   '@NothingButGravy @KeithWoelke @hollyamcd @gardengirl778 @K_G_Andersen @lisa_iannattone I would say that judging by… https://t.co/rLyW3X6g7h',
#   datetime.datetime(2022, 2, 9, 10, 17, 38),
#   'uk'],
#  ['heidiEC5',
#   "RT @latimeralder: Javid\n\n'Over this recent omicron wave, the heroism of those who work in the NHS has shone through once more'\n\nReally? \n\nA…",
#   datetime.datetime(2022, 2, 9, 10, 17, 38),
#   'No Lists Please. #Blocked'],
#  ['ADSutherland_',
#   '@Real_CA03 @Kyle_Irving18 We lost a whole day... 4 I think? I remember fuming as I had Covid and nothing else to do.',
#   datetime.datetime(2022, 2, 9, 10, 17, 37),
#   'London, England'],
#  ['Pimparkha1',
#   "RT @allkpop: Premiere of new SBS drama 'A Business Proposal' starring Ahn Hyo Seop x Kim Se Jung delayed 1 week due to COVID-19 related iss…",
#   datetime.datetime(2022, 2, 9, 10, 17, 37),
#   'กรุงเทพมหานคร, ประเทศไทย'],
#  ['yayaaaa64',
#   'RT @chatshirelore: KMA: “IU, who faced the last year of her 20s with a pleasant momentum, faithfully covered the gloomy music industry, whe…',
#   datetime.datetime(2022, 2, 9, 10, 17, 37),
#   'btsiu '],
#  ['_sourceE',
#   "Don't get COVID https://t.co/XJv71ekSYQ",
#   datetime.datetime(2022, 2, 9, 10, 17, 37),
#   'United States'],
#  ['LadySweetT83',
#   'RT @BreeNewsome: 1) Scientists predict a new spike in Covid cases\n2) We take little to no action\n3) Covid spikes\n4) We take actions we shou…',
#   datetime.datetime(2022, 2, 9, 10, 17, 37),
#   'SHINee World USA'],
#  ['AileanSnaddon',
#   'RT @KwameA009: Yesterday - "Some Covid vaccines could increase risk of HIV infection."\n\nToday - "Trials have now started on an HIV vaccine.…',
#   datetime.datetime(2022, 2, 9, 10, 17, 36),
#   'Bonnie scotland'],
#  ['PaulLeonIsbel',
#   'RT @aussitai: Did Scott Morrison really just say less than 10% of Australians in aged care died of Covid like it was a big win rather than…',
#   datetime.datetime(2022, 2, 9, 10, 17, 36),
#   'Melbourne, Victoria'],
#  ['SuburbanComa',
#   'RT @lindyli: Kevin McCarthy ran away when asked whether 1/6 was legit political discourse\n\nCruz ran away when hundreds froze to death\n\nDeSa…',
#   datetime.datetime(2022, 2, 9, 10, 17, 36),
#   'Charlotte, NC Cleveland, OH '],
#  ['PalestinaPirate',
#   'RT @ExCensorshipose: 🚨| BREAKING: C-19 jabs reach full Poison Status as Double Vaccinated now have highest Case, Hospitalison and Death rat…',
#   datetime.datetime(2022, 2, 9, 10, 17, 36),
#   ''],
#  ['AmIRealIAm',
#   'RT @MarinaPurkiss: Beware the Tory groups\n\nThe ERG - that brought us Brexit\n\nThe Covid Recovery Group - that removed Covid health measures…',
#   datetime.datetime(2022, 2, 9, 10, 17, 36),
#   'Colchester, England'],
#  ['JerryOche2',
#   'RT @NphcdaNG: COVID -19 Vaccination Update: Feb 8th, 2022, in 36 States + the FCT.\n\n15,020,119 of total eligible persons targeted for COVID…',
#   datetime.datetime(2022, 2, 9, 10, 17, 35),
#   'Saint Petersburg, Russia'],
#  ['BBoroimhe',
#   '"...shows vaccine-induced immunity working properly in those who later get COVID-19."\n\nh/t: @Boogaloo2022 https://t.co/znwouesIja',
#   datetime.datetime(2022, 2, 9, 10, 17, 35),
#   'Utopia, Oceania'],
#  ['kentbadboyz',
#   'RT @DaveAtherton20: In Israel it\'s reported "\'80% of serious COVID cases are fully vaccinated\'" says Ichilov hospital director."\n\nVaccine h…',
#   datetime.datetime(2022, 2, 9, 10, 17, 35),
#   ''],
#  ['SoundyPirkko',
#   "RT @dem_cath: Ok What happened to Patrick Vallance and Chris Whitty ? Covid is still here. What happened to Sue Gray's Report ? Stay focuse…",
#   datetime.datetime(2022, 2, 9, 10, 17, 35),
#   ''],
#  ['DixieT13',
#   'Do you think COVID is "over"?\nThink again...\nCovid deaths highest in a year as omicron targets the unvaccinated and… https://t.co/XipySnRFKZ',
#   datetime.datetime(2022, 2, 9, 10, 17, 35),
#   'Here, there, everywhere!'],
#  ['hardlyperennial',
#   'RT @hughosmond: No-one who died of covid in this large CDC studies was NOT suffering from at least one of eight very serious prior conditio…',
#   datetime.datetime(2022, 2, 9, 10, 17, 35),
#   'UK'],
#  ['ashokumer',
#   'RT @CNNBusiness: Krispy Kreme is doubling down on its popular free doughnut promotion for customers vaccinated against Covid-19.  https://t…',
#   datetime.datetime(2022, 2, 9, 10, 17, 34),
#   'Lalganj, India'],
#  ['givepeazachance',
#   "Even the anti people on PEI are saying that the mask mandate being dropped is for tourism operators’ benefit.\n\n'Has… https://t.co/9AV06FdX4o",
#   datetime.datetime(2022, 2, 9, 10, 17, 34),
#   ''],
#  ['thelucyjohnston',
#   'RT @hughosmond: Mass control matched studies show debilitating long covid is incredibly rare. It should not be confused with psychological…',
#   datetime.datetime(2022, 2, 9, 10, 17, 34),
#   'England, United Kingdom'],
#  ['ImVksaini',
#   'RT @bainjal: First Modi blamed poor Dr Harshvardhan for Covid mishandling &amp; sacked him. Now he blames the congress. The buck never stops wi…',
#   datetime.datetime(2022, 2, 9, 10, 17, 34),
#   'Union of India '],
#  ['JUSTICE4SALE',
#   'That I am advised by Counsel and verily believe same to be true that, before a medical product such as Covid-19 vac… https://t.co/0hhoK8PmR1',
#   datetime.datetime(2022, 2, 9, 10, 17, 34),
#   ''],
#  ['KathyLeier1',
#   "RT @JordanSchachtel: Fauci got the memo. The Biden regime saw how bad COVID Mania is polling. It's over. Now they enter the full blown cove…",
#   datetime.datetime(2022, 2, 9, 10, 17, 34),
#   'Hayden, ID'],
#  ['manjuicecom1',
#   'RT @hkfp: Covid-19: Hong Kong malls may see vaccine pass spot checks; CityU warns 250,000 could be infected in fifth wave \n\nhttps://t.co/PN…',
#   datetime.datetime(2022, 2, 9, 10, 17, 33),
#   ''],
#  ['adiaha_young',
#   '@yourstrulyayoub I tell you it’s the best thing. Body actually gets used to fighting off common ailments like it’s… https://t.co/tB1Cf7uSqI',
#   datetime.datetime(2022, 2, 9, 10, 17, 33),
#   'Newcastle Upon Tyne, England'],
#  ['IysseA',
#   "RT @EricTopol: If you thought #LongCovid wasn't a big issue, think again\nhttps://t.co/YKCVKaznVb\nhttps://t.co/DGP8BOW1uW https://t.co/SljzL…",
#   datetime.datetime(2022, 2, 9, 10, 17, 32),
#   ''],
#  ['LlcBillionaire',
#   'WHO: Global COVID-19 case counts decline 17% in latest week  $MRNA $NVAX $PFE https://t.co/raazdmkrbn',
#   datetime.datetime(2022, 2, 9, 10, 17, 32),
#   'New York, USA'],
#  ['bldg_7',
#   'RT @libsoftiktok: This woman took her podcast off Spotify cuz she’s obviously very worried about Covid misinformation and health. https://t…',
#   datetime.datetime(2022, 2, 9, 10, 17, 32),
#   'On a vulcano'],
#  ['epicfighter007',
#   'RT @akash_kolluru: URGENT : My aunt who is fighting for her life at Care Hospital Banjara Hills ( Hyderabad ) requires platelets ASAP. \n\nCo…',
#   datetime.datetime(2022, 2, 9, 10, 17, 32),
#   'Bharatha Kande, Jambooth Dwepe'],
#  ['MFCFoundation',
#   "The @MFCFoundation Boro bus is back at @TeessideUni today. We're there until 5pm with @NHS staff administering firs… https://t.co/7IqOlRppT7",
#   datetime.datetime(2022, 2, 9, 10, 17, 31),
#   'Middlesbrough'],
#  ['saurabhbm',
#   'RT @aginnt: Hundreds of individual protests break out all across Germany tonight to end the COVID police state.\n\nLübeck👇🏼\nhttps://t.co/Z19C…',
#   datetime.datetime(2022, 2, 9, 10, 17, 30),
#   ''],
#  ['DrLindaDykes',
#   'RT @TheRealRhllor: Hey folks. PE is stable, but got "surprise bitched" by another bit of COVID fuckery-acute mesenteric ischemia. Essential…',
#   datetime.datetime(2022, 2, 9, 10, 17, 30),
#   'Rural W Midlands, v near Wales'],
#  ['klasbart',
#   'RT @ErrolWebber: Pfizer reported $36,800,000,000 in COVID vaccine sales in 2021.\n\nJust Pfizer.\n\nIt is now their top selling product — and t…',
#   datetime.datetime(2022, 2, 9, 10, 17, 29),
#   ''],
#  ['ernlaugh',
#   'RT @LBC: Gillian Keegan said she told people she was meeting she tested positive for Covid - but carried on instead of self-isolating\nhttps…',
#   datetime.datetime(2022, 2, 9, 10, 17, 29),
#   'England, United Kingdom'],
#  ['iosaphg',
#   'RT @TomChivers: interesting to see that Danish epidemiologists are complaining about misinformation from British and American Covid hawks s…',
#   datetime.datetime(2022, 2, 9, 10, 17, 29),
#   'The Shire'],
#  ['Spooky_rabbit',
#   "@Destinyshopes @TheLastRefuge2 It's a warning to scientists developing vaccines for high risk HIV areas like sub-Sa… https://t.co/VSnnCwTVEQ",
#   datetime.datetime(2022, 2, 9, 10, 17, 28),
#   'Dark Side of the Moon'],
#  ['1create',
#   "RT @GalacticaZ: At some point, everybody will realize what is going on and what we're up against. But by the time you decide that you've al…",
#   datetime.datetime(2022, 2, 9, 10, 17, 28),
#   ''],
#  ['Eyearwood3',
#   'RT @BabeTruth2: She has died of COVID. I will NEVER UNDERSTAND this. https://t.co/GlBsJWwzd3',
#   datetime.datetime(2022, 2, 9, 10, 17, 28),
#   ''],
#  ['CI20181',
#   'RT @BabeTruth2: She has died of COVID. I will NEVER UNDERSTAND this. https://t.co/GlBsJWwzd3',
#   datetime.datetime(2022, 2, 9, 10, 17, 28),
#   'WITSEC'],
#  ['skry',
#   'RT @EricTopol: Booster protection vs Omicron infection (BA.1) increased from 33% (2-shot vaccine) to 68%, and higher with prior Covid (76%)…',
#   datetime.datetime(2022, 2, 9, 10, 17, 27),
#   'Peripatetic'],
#  ['Sanjaynarula',
#   'RT @firstpost: It has proven that anti-microbial properties with a direct virucidal effect on SARS-CoV-2. NONS, when sprayed over nasal muc…',
#   datetime.datetime(2022, 2, 9, 10, 17, 27),
#   'New Delhi'],
#  ['DemocratPrudent',
#   "RT @Rschooley: The only thing that bothers me about all the attention on Rogan's role in the Covid disinformation grifterverse is it's kind…",
#   datetime.datetime(2022, 2, 9, 10, 17, 27),
#   ''],
#  ['TweeterNight',
#   "@MinWebLit @annatime94 @DrShaneRRR It's the people they spread it to. Their Grandparents, pregnant mothers, cancer… https://t.co/Z73zLgoY6R",
#   datetime.datetime(2022, 2, 9, 10, 17, 27),
#   ''],
#  ['whatisKhaiki',
#   'RT @NPR: The costs of high-quality masks and at-home COVID tests are straining Americans\' finances. "I put off my electric bill, which is o…',
#   datetime.datetime(2022, 2, 9, 10, 17, 26),
#   'United States'],
#  ['JollofRaids',
#   '@Boxing_UK_ @BillyNelsonBox @MartinBakole17 @MTKGlobal @TonyYoka Why was it canceled initially again, Covid related ?',
#   datetime.datetime(2022, 2, 9, 10, 17, 26),
#   ''],
#  ['mymosaicworks',
#   'RT @cateringbm: We are delighted to announce the launch of our new post-Covid brand strategy, outlining our vision for 2022 and beyond. #BM…',
#   datetime.datetime(2022, 2, 9, 10, 17, 25),
#   ''],
#  ['Tonyhobson19',
#   "vine, trump held rallies (super-spreader events) during covid but he wouldn't impose any restrictions so you are, a… https://t.co/pdoJ2w4FME",
#   datetime.datetime(2022, 2, 9, 10, 17, 25),
#   'Nottinghamshire'],
#  ['gfilliman',
#   'RT @joekent16jan19: The Fauci era of lies is coming to an end. We will expose the origins of covid, the role of the CCP &amp; their enablers in…',
#   datetime.datetime(2022, 2, 9, 10, 17, 25),
#   'Sun City, AZ'],
#  ['powys_chc',
#   'RT @PTHBhealth: Drop-in first dose, second dose and booster vaccination sessions TODAY - 9 February.\nNo appointment necessary.\nMore informa…',
#   datetime.datetime(2022, 2, 9, 10, 17, 25),
#   'Brecon Wales / Aberhonddu Cymru'],
#  ['statecraftdaily',
#   'On Tuesday, anti-vaccine protesters gathered in #Australia, #NewZealand inspired by the ongoing #FreedomConvoy demo… https://t.co/atjo5ZtIWL',
#   datetime.datetime(2022, 2, 9, 10, 17, 24),
#   'Mumbai, India'],
#  ['DaveMD123',
#   "RT @axios: $36,800,000,000.\n\nThat's how much Pfizer reported in COVID vaccine sales in 2021 — making it the top-selling pharmaceutical prod…",
#   datetime.datetime(2022, 2, 9, 10, 17, 24),
#   ''],
#  ['Priyalyaduvans4',
#   'RT @PeepingMoon: #EktaKapoor talks about the #pandemic theme in #Naagin6, refutes the claims of #TejasswiPrakash winning #BiggBoss15 becaus…',
#   datetime.datetime(2022, 2, 9, 10, 17, 24),
#   'India'],
#  ['LevBronstein4',
#   "@KinkyLoveLee2 Get dressed FFS it's cold outside you don't wanna catch the COVID",
#   datetime.datetime(2022, 2, 9, 10, 17, 24),
#   ''],
#  ['manjuicecom1',
#   'RT @business: Hong Kong residents haven’t reduced their activity levels as much as they did during previous Covid outbreaks, despite a reco…',
#   datetime.datetime(2022, 2, 9, 10, 17, 24),
#   ''],
#  ['ItsTalking',
#   'RT @KwameA009: Pfizer is worried that the release of 55,000 pages of clinical and safety data will impact business despite their vaccine be…',
#   datetime.datetime(2022, 2, 9, 10, 17, 23),
#   ''],
#  ['CI20181',
#   'RT @BabeTruth2: @Kreidbicloudco1 Nurses can lose their license now for spreading COVID misinformation while on duty. Thank goodness,',
#   datetime.datetime(2022, 2, 9, 10, 17, 23),
#   'WITSEC'],
#  ['JiBA67035130',
#   '@PhathaPhatha2 Lol Covid reg',
#   datetime.datetime(2022, 2, 9, 10, 17, 23),
#   ''],
#  ['KateAus1976',
#   "RT @ByLucyJones: Justin Trudeau's brother @KyleKemper will be joining @DanWootton tonight to talk about the Canadian truckers' Freedom Conv…",
#   datetime.datetime(2022, 2, 9, 10, 17, 23),
#   ''],
#  ['GE_1970',
#   'RT @splootman: Gillian Keegan ,health minister, now apologising after testing positive for Covid during a meeting but keeping it secret and…',
#   datetime.datetime(2022, 2, 9, 10, 17, 23),
#   'North East, England'],
#  ['JohnBro26716300',
#   "RT @Matthew82069336: The health and wellbeing of citizens should be of paramount importance to any Government.That is of course unless you'…",
#   datetime.datetime(2022, 2, 9, 10, 17, 23),
#   'Chester, England'],
#  ['tiscachopraa',
#   'China has ordered inhabitants of the southern city of Baise to stay home and suspended transportation links amid a… https://t.co/pOZwxI4hLe',
#   datetime.datetime(2022, 2, 9, 10, 17, 22),
#   ''],
#  ['lipsyLui',
#   'RT @Kevin_Maguire: Another clear case of Covid rule breaking by a Conservative politician in power...this time a HEALTH Minister.\n\nGillian…',
#   datetime.datetime(2022, 2, 9, 10, 17, 22),
#   ''],
#  ['27b2a9fa16ff4a8',
#   'RT @GreenSwelfares: Covid-19 Vaccination Camp following the pious teachings of Saint Dr. Gurmeet 𝐑𝐚𝐦 𝐑𝐚𝐡𝐢𝐦 Singh Ji Insan | DSS Volunteers…',
#   datetime.datetime(2022, 2, 9, 10, 17, 22),
#   ''],
#  ['moli_erreala',
#   'RT @onisillos: “Corporations like Pfizer should never have been put in charge of a global vaccination rollout, because it was inevitable th…',
#   datetime.datetime(2022, 2, 9, 10, 17, 22),
#   'Donostia, Basque Country'],
#  ['philipmalberto4',
#   'Queen - Keep Yourself Alive (Official Video) https://t.co/su9huEnOml via @YouTube  The theme song for a COVID-19 era for the world!',
#   datetime.datetime(2022, 2, 9, 10, 17, 21),
#   ''],
#  ['powys_chc',
#   'RT @PTHBhealth: If you live in south west Powys (and you are aged 18+ and due a COVID vaccine) then you can also drop in for COVID vaccinat…',
#   datetime.datetime(2022, 2, 9, 10, 17, 21),
#   'Brecon Wales / Aberhonddu Cymru'],
#  ['Janet45220381',
#   'RT @runtokeepup: Gillian keegan taking a precautionary covid test before a meeting then going ahead with the meeting without waiting for th…',
#   datetime.datetime(2022, 2, 9, 10, 17, 21),
#   ''],
#  ['chrisoconnor123',
#   "RT @Silverhawk13: Update. I don't know how many people saw the post that my 2yo grandson has COVID, but he is now at urgent care with a hig…",
#   datetime.datetime(2022, 2, 9, 10, 17, 21),
#   'Alexandria, Virginia'],
#  ['Dinopundz',
#   'Ghana’s COVID-19 infection rate remain lower compared to other countries with far higher vaccination rates.#DropVaccineMandates',
#   datetime.datetime(2022, 2, 9, 10, 17, 21),
#   'Tema'],
#  ['NoyonKh64603580',
#   '@CryptocountryC5 @CraoToken The Covid-19 pandemic season weakened economies around the world. What did the Defi pro… https://t.co/JzX0JtU5kk',
#   datetime.datetime(2022, 2, 9, 10, 17, 20),
#   ''],
#  ['Nordic_News',
#   "Denmark's Queen Margrethe has tested positive for covid-19 https://t.co/eNIW5n1ilc",
#   datetime.datetime(2022, 2, 9, 10, 17, 20),
#   'Northern Europe'],
#  ['bloodyazalea',
#   'Covid positive. I can officially take 7 days off work 🎉🎉🎉\n\nI only have very mild symptoms so all good 👍',
#   datetime.datetime(2022, 2, 9, 10, 17, 20),
#   ''],
#  ['indiecratublic1',
#   "RT @blackfemicideUS: Black-owned businesses took a pandemic hit, but they're doing better than ever now — largely because of Black women ht…",
#   datetime.datetime(2022, 2, 9, 10, 17, 20),
#   ''],
#  ['WitchesKitchen',
#   'RT @Kevin_Maguire: Another clear case of Covid rule breaking by a Conservative politician in power...this time a HEALTH Minister.\n\nGillian…',
#   datetime.datetime(2022, 2, 9, 10, 17, 19),
#   'England, United Kingdom'],
#  ['ResearchPool',
#   '$QIA #QIAGEN NV Qiagen : Excellent finish to the year, first 2022 guidance a good floor: &gt;Both non-Covid and Covid-… https://t.co/N5uNs14ahl',
#   datetime.datetime(2022, 2, 9, 10, 17, 19),
#   'Paris, France'],
#  ['heidiEC5',
#   'RT @YardleyShooting: This is what the Joint Committee on Vaccination and Immunisation said on vaccination of 5-11 year olds: "The benefits…',
#   datetime.datetime(2022, 2, 9, 10, 17, 19),
#   'No Lists Please. #Blocked'],
#  ['quinnellsusan',
#   'RT @sharron_honey: https://t.co/Rj9AOkKLbS\nHealth minister Gillian Keegan apologises for continuing in-person meeting despite positive COVI…',
#   datetime.datetime(2022, 2, 9, 10, 17, 19),
#   'Somerset'],
#  ['kennypowders76',
#   'RT @Togetherdec: Millions awaiting treatment - a direct result of gov policy &amp; “Covid Only” obsession \n\nWe need all the brave frontline sta…',
#   datetime.datetime(2022, 2, 9, 10, 17, 18),
#   'Scotland, United Kingdom'],
#  ['LisaZucker3',
#   'RT @j951: America 2022: Where Everyone Has Rights and No One Has Responsibilities https://t.co/aGnuCjiLhh',
#   datetime.datetime(2022, 2, 9, 10, 17, 18),
#   'Austin, TX & California'],
#  ['SweetPeatrsburg',
#   'RT @BabeTruth2: She has died of COVID. I will NEVER UNDERSTAND this. https://t.co/GlBsJWwzd3',
#   datetime.datetime(2022, 2, 9, 10, 17, 18),
#   'West Coast Floriduh'],
#  ['zarark111',
#   '@Deepalis1612 @itsfacist @Jaim0134 @desimojito @priyankagandhi I have enough time Covid untimed lockdown cost me my… https://t.co/yYesbGFcpg',
#   datetime.datetime(2022, 2, 9, 10, 17, 18),
#   'Imaginary world'],
#  ['paullombardi2',
#   '@Scary7Dr Does this translate into everyone being honest instead of amalgamating vaccine, Remdesivir, ventilator, "… https://t.co/sLUPLHHfUc',
#   datetime.datetime(2022, 2, 9, 10, 17, 18),
#   'Phantom University...'],
#  ['Mavsmummmy',
#   'RT @TonyHinton2016: Vitamin D vitamin C and zinc. All good for your immune system and all have a positive effect against risks from covid.…',
#   datetime.datetime(2022, 2, 9, 10, 17, 18),
#   ''],
#  ['wineonthesofa',
#   'Ladies and Gentlemen, I give you our “Health Minister”\n\nhttps://t.co/G7YPMVmuo3 Health minister Gillian Keegan apol… https://t.co/g55J1P9B2V',
#   datetime.datetime(2022, 2, 9, 10, 17, 18),
#   ''],
#  ['manuel_bolio',
#   'RT @DrEricDing: 7) Virus researcher &amp; chief physician of 🇩🇰’s CDC @ssi_dk  says you can get **reinfected with #BA2 sub-variant** of #Omicro…',
#   datetime.datetime(2022, 2, 9, 10, 17, 18),
#   'Mérida, Yucatán principalmente'],
#  ['Izzatscarlet',
#   '@elkrstyyy Oh yeahh and stay safe too since covid cases quite increase day by day',
#   datetime.datetime(2022, 2, 9, 10, 17, 17),
#   ''],
#  ['CanalBrocante',
#   'RT @joolegill: So in today’s news British holiday makers are bleating that Covid entry requirements are different in Spain, France and othe…',
#   datetime.datetime(2022, 2, 9, 10, 17, 17),
#   'Central Brittany'],
#  ['steve_evo',
#   'RT @Iloveautumn2: Another 405 people died of #Covid yesterday. Never, ever forget that the Tories partied while people died alone. Never fo…',
#   datetime.datetime(2022, 2, 9, 10, 17, 17),
#   ''],
#  ['AlAkBseth',
#   'RT @MukandRita: COVID spread through International travel not migrants. PM Modi spread it by having Nameste Trump even after  WHO warned.…',
#   datetime.datetime(2022, 2, 9, 10, 17, 17),
#   ''],
#  ['J9P814',
#   'RT @VPrasadMDMPH: Yes, COVID is on par with Flu in terms of risk to kids, but more to the point, the amount of restrictions we placed on ch…',
#   datetime.datetime(2022, 2, 9, 10, 17, 17),
#   ''],
#  ['chamomile114',
#   'RT @LeyshaSenyum: my husband has had to go into the office these past two days. today he got a notification that someone in his office is C…',
#   datetime.datetime(2022, 2, 9, 10, 17, 17),
#   'MY'],
#  ['wsbgnl',
#   'It’s surprising how many medical experts seem to have no idea that the majority of people can’t simply “choose” the… https://t.co/thYNEsKFZq',
#   datetime.datetime(2022, 2, 9, 10, 17, 16),
#   'Seattle'],
#  ['STogetherNI',
#   "RT @healthdpt: This week's Covid-19 vaccination clinics across NI 👇\n\nFirst dose, second dose and booster jabs available.\n\nFind your local c…",
#   datetime.datetime(2022, 2, 9, 10, 17, 16),
#   'Northern Ireland'],
#  ['GoranOstrom',
#   '@GostaBroholmer Expert says ‘we’re sitting ducks for this next wave’ of COVID-19',
#   datetime.datetime(2022, 2, 9, 10, 17, 16),
#   ''],
#  ['DelthiaRicks',
#   "RT @DelthiaRicks: 2,500 people are dying daily of Covid but the narrative in governors' mansions and news reports is this — we've passed th…",
#   datetime.datetime(2022, 2, 9, 10, 17, 16),
#   'New York'],
#  ['alissonfeijaum',
#   'RT @DrEricDing: ⚠️SUB-VARIANT SURGING—Omicron 2.0 is rising—the #BA2 sublineage of #Omicron has *tripled* in one week, dislodging the old O…',
#   datetime.datetime(2022, 2, 9, 10, 17, 15),
#   'Cruz das Almas, Brasil'],
#  ['Doo54697914',
#   'RT @XHNews: Chile records 24,970 new COVID-19 infections in 24 hours, a slight decrease compared to the numbers of recent days, as well as…',
#   datetime.datetime(2022, 2, 9, 10, 17, 15),
#   ''],
#  ['FlynnTinka76',
#   'RT @OTURISK: I have sent a copy of this document to a number of prominent GPs in Ireland ,and the ICGP. WARNING  I will testify to that ,at…',
#   datetime.datetime(2022, 2, 9, 10, 17, 15),
#   ''],
#  ['ItsTalking',
#   "Pfizer Quietly Adds Language Warning That 'Unfavorable Pre-Clinical, Clinical Or Safety Data' May Impact Business\nhttps://t.co/w9Ny0U0LMS",
#   datetime.datetime(2022, 2, 9, 10, 17, 15),
#   ''],
#  ['Rburd1',
#   'RT @ErrolWebber: Pfizer reported $36,800,000,000 in COVID vaccine sales in 2021.\n\nJust Pfizer.\n\nIt is now their top selling product — and t…',
#   datetime.datetime(2022, 2, 9, 10, 17, 15),
#   ''],
#  ['AmericanDad2017',
#   "RT @Real_iTamara: Do you think they are mad that more of us didn't die during their little covid experiment?",
#   datetime.datetime(2022, 2, 9, 10, 17, 15),
#   'Maryland, USA'],
#  ['bebop24',
#   'RT @ErrolWebber: Pfizer reported $36,800,000,000 in COVID vaccine sales in 2021.\n\nJust Pfizer.\n\nIt is now their top selling product — and t…',
#   datetime.datetime(2022, 2, 9, 10, 17, 14),
#   ''],
#  ['LewtonSerena5',
#   'RT @DominiqueTaegon: Concerning that this consultation for Human Rights Act reform wants to ‘balance’ our use of ‘rights’ vs. ‘wider societ…',
#   datetime.datetime(2022, 2, 9, 10, 17, 14),
#   'Great  Britain '],
#  ['GaryHar29901446',
#   "Got my CHINA made covid 19 antigen rapid self-test in the mail yesterday!! I'm sending it back to California. Wonde… https://t.co/EHl5PKKGG1",
#   datetime.datetime(2022, 2, 9, 10, 17, 14),
#   ''],
#  ['mymosaicworks',
#   'RT @Facilitate_Mag: NEWS: @cateringbm announces its post-Covid strategy\n#FacMan #Catering \nhttps://t.co/h0RTZ7tVFx',
#   datetime.datetime(2022, 2, 9, 10, 17, 14),
#   ''],
#  ['PeterChave3',
#   'RT @coaimpaul: Those accused of claiming benefits ‘illegally’ are crucified as scroungers. Tories steal hundreds of millions of pounds from…',
#   datetime.datetime(2022, 2, 9, 10, 17, 14),
#   ''],
#  ['halligram',
#   'RT @newsmax: Rep. Chip Roy of Texas introduced a bill that would reinstate troops who were fired for refusing to take the COVID-19 vaccine.…',
#   datetime.datetime(2022, 2, 9, 10, 17, 14),
#   'Londonderry NH'],
#  ['MirabellaMB',
#   "@pimpi59 You don't get tested for cold and flu and work as long as you are able. We test for covid mostly to quarantine.",
#   datetime.datetime(2022, 2, 9, 10, 17, 14),
#   'The lost moon of Poosh '],
#  ['LesleyMillingt5',
#   "RT @JordanSchachtel: Fauci got the memo. The Biden regime saw how bad COVID Mania is polling. It's over. Now they enter the full blown cove…",
#   datetime.datetime(2022, 2, 9, 10, 17, 14),
#   ''],
#  ['MsMickeyWright',
#   'RT @GovNL: ⚠ Public Advisory: Further Easing of a Number of COVID-19 Restrictions \n\nText version here: https://t.co/Y6Hy40PYVJ #GovNL https…',
#   datetime.datetime(2022, 2, 9, 10, 17, 14),
#   ''],
#  ['BLKROCKET',
#   'maybe men have a harder time with grief, breakups, loss, being alone. they die soon. they fill the dark with suicid… https://t.co/BdWSeTHXTa',
#   datetime.datetime(2022, 2, 9, 10, 17, 14),
#   'Naked Blue Planet'],
#  ['KataHikmahFakta',
#   'RT @NewsBFM: 1. 24-hour mamak eateries in Malaysia may become a thing of the past, even if Covid-19 restrictions are lifted.\n\nThe Malaysian…',
#   datetime.datetime(2022, 2, 9, 10, 17, 14),
#   'Bangi'],
#  ['tufong57',
#   'RT @awarrior828: The media hides important key factors. They leave out the part where everything connects. Our mind body and soul connect.…',
#   datetime.datetime(2022, 2, 9, 10, 17, 13),
#   ''],
#  ['TanyaMorris127',
#   'RT @DanaLoeschRadio: "..we gave financial incentives for hospitals to count deaths as COVID whether they were from it or not"\n\n@RandPaul ex…',
#   datetime.datetime(2022, 2, 9, 10, 17, 13),
#   ''],
#  ['stansburydl',
#   'RT @VPrasadMDMPH: Yes, COVID is on par with Flu in terms of risk to kids, but more to the point, the amount of restrictions we placed on ch…',
#   datetime.datetime(2022, 2, 9, 10, 17, 13),
#   ''],
#  ['bitsiouni',
#   'I am pleased to announce the release of our report which examines non-custodial sanctions and measures in Cyprus, w… https://t.co/qHZ89TcVho',
#   datetime.datetime(2022, 2, 9, 10, 17, 13),
#   'Cyprus'],
#  ['Chitrajeevnath',
#   'RT @TOIChennai: 87% of Tamil Nadu people had antibodies against SARS-CoV-2 before third Covid-19 wave: Serosurvey https://t.co/VjjU4Lv301',
#   datetime.datetime(2022, 2, 9, 10, 17, 13),
#   'Chennai, India'],
#  ['pbcfac1',
#   'RT @coaimpaul: Those accused of claiming benefits ‘illegally’ are crucified as scroungers. Tories steal hundreds of millions of pounds from…',
#   datetime.datetime(2022, 2, 9, 10, 17, 12),
#   'Reading, UK'],
#  ['mamalla76375383',
#   'RT @PeterSweden7: Saskatchewan in Canada has announced they will be REMOVING the use of covid passports next week and ending mask mandates…',
#   datetime.datetime(2022, 2, 9, 10, 17, 12),
#   ''],
#  ['vinagr24',
#   'RT @himantabiswa: By developing &amp; manufacturing Covid vaccines, India proved its mettle to the world. It also shows that when Adarniya PM S…',
#   datetime.datetime(2022, 2, 9, 10, 17, 12),
#   ''],
#  ['SefetiB',
#   'RT @RichardKNaidu: The economy has crashed 24%, the West is recovering from floods, tens of thousands remain jobless after Covid - and what…',
#   datetime.datetime(2022, 2, 9, 10, 17, 12),
#   'Fiji'],
#  ['Geminorn',
#   'RT @DrEricDing: 🧬Wow—REAWAKENING ancient virus remnants in human DNA—new study finds #SARSCoV2 “can induce (dormant) HERV-W ENV expression”…',
#   datetime.datetime(2022, 2, 9, 10, 17, 12),
#   ''],
#  ['Bibbeth6',
#   "RT @cccammy1: Can someone explain why people in Berwick who don't have face masks are not dying of Covid, but 3 miles away in Scotland, mas…",
#   datetime.datetime(2022, 2, 9, 10, 17, 11),
#   'Scotland, United Kingdom'],
#  ['News18Telugu',
#   '71-year-old Girija was unsure about COVID-19 vaccines. Till volunteers from the largest vaccine awareness drive,… https://t.co/spiDosnazS',
#   datetime.datetime(2022, 2, 9, 10, 17, 10),
#   'Hyderabad, India'],
#  ['ysabel',
#   'RT @Kit_Yates_Maths: The government\'s own coronavirus rules say an individual must isolate "straight away" if they record a positive latera…',
#   datetime.datetime(2022, 2, 9, 10, 17, 10),
#   'Denver, Colorado, USA'],
#  ['rxbbie_ap',
#   'Wordle 235 4/6\n\nWe recovering from covid iktr\n\n\U0001f7e8⬛⬛⬛\U0001f7e8\n\U0001f7e9\U0001f7e8\U0001f7e8⬛⬛\n\U0001f7e9⬛⬛\U0001f7e8\U0001f7e8\n\U0001f7e9\U0001f7e9\U0001f7e9\U0001f7e9\U0001f7e9',
#   datetime.datetime(2022, 2, 9, 10, 17, 10),
#   'London, England'],
#  ['Brownscrossing7',
#   "RT @elleprovocateur: Yesterday's #ID2020 is today's Good Health Pass, is tomorrows Digital Identity for All.\n\n#Freedom-As-A-Service\n\nThe co…",
#   datetime.datetime(2022, 2, 9, 10, 17, 10),
#   ''],
#  ['themoment767',
#   '@Barking_Digits @LittleMissMaryB I’ve never caught heart disease games night with my friend! \n\nHowever, I have caug… https://t.co/O6PKeOr7gU',
#   datetime.datetime(2022, 2, 9, 10, 17, 10),
#   'Canada'],
#  ['AHamiedNHS',
#   'RT @BWCHBoss: A true pleasure to welcome \u2066@Emily_JR_Lawson\u2069 to Birmingham and Solihull today to share the highs, lows and lessons from our…',
#   datetime.datetime(2022, 2, 9, 10, 17, 9),
#   'Rochdale'],
#  ['Openatlast',
#   '@SaveTheNHS4U @GraceNoted @StaveleyMWFCNo1 @JohnDalton6011 Yet 170 000 have died from Covid. Thatcher KNIGHTED savi… https://t.co/OvlMCC1cGR',
#   datetime.datetime(2022, 2, 9, 10, 17, 9),
#   ''],
#  ['underoneceiling',
#   'WHO urges rich countries to pay up for Covid\xa0plan https://t.co/aCu56MCkGH',
#   datetime.datetime(2022, 2, 9, 10, 17, 9),
#   ''],
#  ['mroller98',
#   "RT @willis_macp: Joe Clarke is among England's (non-travelling) Covid/injury reserves for the tour of the West Indies next month https://t.…",
#   datetime.datetime(2022, 2, 9, 10, 17, 8),
#   'London'],
#  ['loulou34f',
#   'RT @MattGubba: To anyone wondering why there would be a sudden push for HIV tests... the answer is simple. \n\nAs testing for covid tails off…',
#   datetime.datetime(2022, 2, 9, 10, 17, 8),
#   ' Scotland'],
#  ['pennylane1357',
#   "RT @itosettiMD_MBA: Repeated cycles \nof covid mass infection \npretending all is normal \ndon't seem like a solid plan.",
#   datetime.datetime(2022, 2, 9, 10, 17, 8),
#   'Plague Island'],
#  ['DrLindaDykes',
#   '@TheRealRhllor Oh heavens, and that would have been despite anti coagulation for your PE? You are having such a rough ride. Bloody covid 😡',
#   datetime.datetime(2022, 2, 9, 10, 17, 8),
#   'Rural W Midlands, v near Wales'],
#  ['EdmJbg',
#   '@MarcTennant WHAT? \n\nThe UK is “past the point” where vaccinating young, healthy children against Covid-19 will do… https://t.co/12anrzVOqW',
#   datetime.datetime(2022, 2, 9, 10, 17, 8),
#   'World'],
#  ['KerrieMengersen',
#   'RT @MATRIX_Inst: Coming up! Prof. James McCaw @j_mccaw presents "Epidemic modelling to support Australia’s COVID-19 planning and response."…',
#   datetime.datetime(2022, 2, 9, 10, 17, 8),
#   'Brisbane, Queensland'],
#  ['BerkleyBearNews',
#   "'Destroyed': Afghanistan's health system crumbles as COVID-19 wave surges https://t.co/c7Qq73M7Sz #news #berkleybearnews",
#   datetime.datetime(2022, 2, 9, 10, 17, 7),
#   'Doghouse'],
#  ['CarnageMovie',
#   'RT @AP_Europe: Sweden has halted wide-scale testing for COVID-19 even among people showing symptoms of an infection… https://t.co/l2BQOTohzk',
#   datetime.datetime(2022, 2, 9, 10, 17, 7),
#   'MichaelJosephMiller@email.com'],
#  ['irish_today',
#   'RT @irishexaminer: Sweden ends Covid testing as pandemic restrictions lifted https://t.co/zSQttpOYbO',
#   datetime.datetime(2022, 2, 9, 10, 17, 7),
#   ''],
#  ['MarcusNueva',
#   '@RNCResearch Zero covid transmission? Do these people even know what viruses are? They are here to stay long after all of us are gone…',
#   datetime.datetime(2022, 2, 9, 10, 17, 7),
#   'across the pacific'],
#  ['tiossinob',
#   'RT @DrJBhattacharya: This fantastic tweet thread by @WashburneAlex calls out abusive covidian scientists, now proven wrong on every particu…',
#   datetime.datetime(2022, 2, 9, 10, 17, 7),
#   ''],
#  ['KemJess',
#   'RT @TheTPatriots: Five (5) COVID-19 government tax reliefs aside from the E-Levy brouhaha. #BuildingGhanaTogether https://t.co/zRFJCW3qlt',
#   datetime.datetime(2022, 2, 9, 10, 17, 7),
#   'Accra, Ghana'],
#  ['NesihToprak',
#   'RT @Alien_Scientist: Happy "Winter of severe illness and death"!\nHere\'s a free official White House Crack Pipe so you don\'t spread covid wh…',
#   datetime.datetime(2022, 2, 9, 10, 17, 6),
#   'Leuven, België'],
#  ['sinijay8',
#   'RT @sarithairugal: In bed nursing a particularly horrible day of sore throat thanks to Covid, and thinking about this peaceful week of beac…',
#   datetime.datetime(2022, 2, 9, 10, 17, 6),
#   ''],
#  ['blobrana',
#   'RT @westportskyguys: It is supposed to be clear tonight 2/9, so the #WestportObservatory will be open. Recently we closed due to the COVID…',
#   datetime.datetime(2022, 2, 9, 10, 17, 6),
#   '( Location: Pictland )'],
#  ['LizWarburton',
#   'RT @MarinaPurkiss: Beware the Tory groups\n\nThe ERG - that brought us Brexit\n\nThe Covid Recovery Group - that removed Covid health measures…',
#   datetime.datetime(2022, 2, 9, 10, 17, 6),
#   ''],
#  ['ToyerToys',
#   'No, the alpha and beta variants of the coronavirus aren’t circulating in the US - https://t.co/1sPJVhX3NM https://t.co/Di2keCFnXH',
#   datetime.datetime(2022, 2, 9, 10, 17, 6),
#   'United Arab Emirates'],
#  ['evansdanielm',
#   '@VodafoneUK It seems crazy to me that you have no allowance for flexibility on the ASTRONOMICAL cancellation fees d… https://t.co/y74u4njYC8',
#   datetime.datetime(2022, 2, 9, 10, 17, 6),
#   'Raleigh, NC to London, UK'],
#  ['GillSels',
#   '@JonahLupton They reported increased supply chain and project costs due to covid last quarter, will be interesting… https://t.co/1LCBwVDw7W',
#   datetime.datetime(2022, 2, 9, 10, 17, 6),
#   ''],
#  ['BuzzBeardy',
#   'RT @mdccclxx: TL;DR\n1.Moderna is an $80billion company with a "God complex" (in the literal sense) that, prior to its COVID mRNA vaccine, h…',
#   datetime.datetime(2022, 2, 9, 10, 17, 5),
#   'London, England'],
#  ['komiska',
#   'RT @PopSci: Anthony Fauci and other public health experts give us their roadmap for the rest of the pandemic. https://t.co/JuTWv6GQcv',
#   datetime.datetime(2022, 2, 9, 10, 17, 5),
#   'kiel, germany'],
#  ['Reeve98Mark',
#   'Typical Tory values\nDo wrong\nGet supported\nCarry on regardless\nShame @sajidjavid your predecessor didn’t have that… https://t.co/SKQtoOwPSx',
#   datetime.datetime(2022, 2, 9, 10, 17, 5),
#   ''],
#  ['Taka_xoxo_NZ',
#   "RT @nzherald: 'Traumatised': Mask-wearing girl egged, abused by convoy protesters https://t.co/Gm8AmN5ntV https://t.co/Y8iNuYEFVu",
#   datetime.datetime(2022, 2, 9, 10, 17, 5),
#   'Auckland Newzealand'],
#  ['tejaasswi',
#   'RT @PeepingMoon: #EktaKapoor talks about the #pandemic theme in #Naagin6, refutes the claims of #TejasswiPrakash winning #BiggBoss15 becaus…',
#   datetime.datetime(2022, 2, 9, 10, 17, 5),
#   'India'],
#  ['skry',
#   'RT @VirusesImmunity: Nasal Spray Booster Keeps COVID-19 at Bay - an excellent piece by Meghan Rosen.\n\nSo grateful to @HHMINEWS for stepping…',
#   datetime.datetime(2022, 2, 9, 10, 17, 4),
#   'Peripatetic'],
#  ['jjdemul',
#   'RT @ezralevant: Kenney just said we\'ll probably need to "take an annual Covid shot".\n\nHe\'s saying all this. An annual shot.\n\nHoly shit.',
#   datetime.datetime(2022, 2, 9, 10, 17, 4),
#   'www.bnmo.nl'],
#  ['laudermk60',
#   "@mehdirhasan And u don't even believe those numbers yourself..give me a break..almost no one that I know who has di… https://t.co/xiKQTdBVKp",
#   datetime.datetime(2022, 2, 9, 10, 17, 4),
#   ''],
#  ['roger_mm1',
#   "RT @section_117: Mcgowan's state tyranny continues seeing rogue Police blockading TOPOLINI'S, a Perth WA restaurant arresting the owner and…",
#   datetime.datetime(2022, 2, 9, 10, 17, 4),
#   'Lightning Ridge, New South Wales'],
#  ['LLMN80',
#   'RT @TaniaSp05818956: I have been saying this for 23 months. A clear chest x-ray and apparently healthy pulse oximetry do not mean you are f…',
#   datetime.datetime(2022, 2, 9, 10, 17, 4),
#   'Stuttgart, Deutschland'],
#  ['upenditall',
#   'RT @ChuckCallesto: BREAKING REPORT: Alberta Canada Premier ENDS COVID VACCINE PASSPORT SYSTEM – Effective Tonight at Midnight...',
#   datetime.datetime(2022, 2, 9, 10, 17, 4),
#   'United States'],
#  ['iki_bmu',
#   'Protecting vulnerable #valuechains in the face of Covid-19: find out how the "Rebuild Facility" supports environmen… https://t.co/rh7VpmP9Wa',
#   datetime.datetime(2022, 2, 9, 10, 17, 4),
#   'Berlin, Germany'],
#  ['SabnamBarsha',
#   'RT @PeepingMoon: #EktaKapoor talks about the #pandemic theme in #Naagin6, refutes the claims of #TejasswiPrakash winning #BiggBoss15 becaus…',
#   datetime.datetime(2022, 2, 9, 10, 17, 3),
#   ''],
#  ['TALK1370',
# ...
#   datetime.datetime(2022, 2, 9, 10, 14, 48),
#   'USA'],
#  ['maxwithaxe',
#   '@DebbieGarratt Murdering children to increase corporate profits. We need covid Nuremberg trials to bring these criminals to justice.',
#   datetime.datetime(2022, 2, 9, 10, 14, 48),
#   'The Dark Ages'],
#  ['avfc_views',
#   'Back to Villa Park tonight, absolutely buzzing.\n\nFeels like ages (missed Man U due to COVID!)\n\n#avfc',
#   datetime.datetime(2022, 2, 9, 10, 14, 48),
#   ''],
#  ['CanesDawgSicEm',
#   'RT @RepThomasMassie: What the?!\n“As COVID restrictions continue to decrease nationwide, increased access to commercial and government facil…',
#   datetime.datetime(2022, 2, 9, 10, 14, 48),
#   '‘Round Yonder'],
#  ['dreamingoftheg1',
#   'RT @Sophie51403248: This report is a few weeks old now but,at this stage 68.9% of the UK had at least 1 jab. Within the time period of this…',
#   datetime.datetime(2022, 2, 9, 10, 14, 48),
#   ''],
#  ['OdhiamboOlela',
#   'RT @ypluskenya: Join Our Tausi Taskforce representatives as they speak on the need of making informed decisions about their SRH during this…',
#   datetime.datetime(2022, 2, 9, 10, 14, 48),
#   'Nairobi, Kenya'],
#  ['SuperDuuperKyle',
#   '@Decobra_ @Eymoi_Jnr Covid was from the devil but God had his hand in the creation of this vaccine, he has a hand i… https://t.co/ngby47U9yl',
#   datetime.datetime(2022, 2, 9, 10, 14, 48),
#   ''],
#  ['MANAQVI2022',
#   "RT @AKondakor: @LloydHardy Such a hard choice.\nAnd don't forget leveling up, net zero and climate change, COVID response, #Brexit of course…",
#   datetime.datetime(2022, 2, 9, 10, 14, 48),
#   ''],
#  ['Bob40713222',
#   '@GillianKeegan Are you going to resign? Of course not, this is the Boris government: if someone in your meeting die… https://t.co/vqUykjUrYM',
#   datetime.datetime(2022, 2, 9, 10, 14, 47),
#   ''],
#  ['NshabaDaniel',
#   'RT @DrJohnB2: Lymphadenopathy after #CovidVaccination with increased FDG uptake: https://t.co/WjRx5lyS4W\n- "Our results revealed that lymph…',
#   datetime.datetime(2022, 2, 9, 10, 14, 47),
#   'Uganda'],
#  ['grohmann_rafael',
#   'RT @platformmobili1: On the (slow) progress of automation in warehouses. At the same time, Amazon has hired more than 500.000 workers since…',
#   datetime.datetime(2022, 2, 9, 10, 14, 47),
#   'Porto Alegre, Brasil'],
#  ['LMcjury',
#   'RT @TheLastPersont2: Tory brexit disaster, tory covid catastrophe, child food poverty, energy crisis...\n\nNever mind all the lies, hypocrisy…',
#   datetime.datetime(2022, 2, 9, 10, 14, 47),
#   'England, United Kingdom'],
#  ['PrshotsR',
#   'Coty’s quarterly revenue was down on estimates but it has raised its profit expectations for the year, as it focuse… https://t.co/78jDnhPukb',
#   datetime.datetime(2022, 2, 9, 10, 14, 46),
#   'London'],
#  ['ClarkMstracey',
#   'RT @Toure: I just got free Covid tests in the mail from the gov. Biden gave me Covid tests, Obama gave me a phone, Trump gave me crippling…',
#   datetime.datetime(2022, 2, 9, 10, 14, 46),
#   'Indiana, USA'],
#  ['drmpagra',
#   'RT @THMetroPlus: What should you eat once you’ve recovered from #COVID19 and are out of #quarantine? @nivi15 and @soma1807 speak to healthc…',
#   datetime.datetime(2022, 2, 9, 10, 14, 45),
#   'Agra, India'],
#  ['SimpliArt',
#   'RT @Haggis_UK: Susanna Reid - Gillian Keegan has apologised for continuing with an in-person meeting despite being told she had tested posi…',
#   datetime.datetime(2022, 2, 9, 10, 14, 44),
#   'London'],
#  ['SOshlys',
#   'RT @GlobalJusticeUK: "Corporations like #Pfizer should never have been put in charge of a global vaccination rollout because it was inevita…',
#   datetime.datetime(2022, 2, 9, 10, 14, 44),
#   'Scotland, UK'],
#  ['CameronRenilson',
#   "RT @Birdyword: Japan's reported daily Covid cases have passed the US level for the first time since March 10, 2020 https://t.co/EA8fdHplHD",
#   datetime.datetime(2022, 2, 9, 10, 14, 44),
#   'Planet Earth - Down Under'],
#  ['cjmays01c',
#   'RT @suckitjackbootz: Narrative unravels\n\nNext plandemic being prepared for\n\nAlllll a frickin show\n\nhttps://t.co/KDTLtubIr4',
#   datetime.datetime(2022, 2, 9, 10, 14, 44),
#   'Colorado, Brighton'],
#  ['Allchanges',
#   "RT @johncurnow7: The Tories have worked out how to save on our pensions.If Covid does'nt get you,working till you drop shold do the trick",
#   datetime.datetime(2022, 2, 9, 10, 14, 44),
#   ''],
#  ['RXIL_TReDS',
#   "Here's a snapshot of the highlights addressed by our Finance Minister Nirmala Sitharaman in light of the covid-19 p… https://t.co/T89rfDAPvh",
#   datetime.datetime(2022, 2, 9, 10, 14, 44),
#   'Mumbai, India'],
#  ['Shaunnotsharon',
#   "RT @dgurdasani1: So please spare me your scepticism of long COVID 'self-reported' studies, because how else would you examine this, at this…",
#   datetime.datetime(2022, 2, 9, 10, 14, 44),
#   'Galera, España'],
#  ['K2020Cat',
#   'RT @ProfTimBale: "Policies in Germany and Denmark placed care homes on a more or less equal footing with hospitals from early in the pandem…',
#   datetime.datetime(2022, 2, 9, 10, 14, 43),
#   'United Kingdom'],
#  ['intentShared',
#   'RT @paix120: A professor I know asked their college class today how many Americans died from COVID in January, and some students guessed "a…',
#   datetime.datetime(2022, 2, 9, 10, 14, 43),
#   'nyc'],
#  ['wokingcouncil',
#   "RT @DHSCgovuk: The offer of a #COVID19 vaccination will always be available for anyone who hasn't had theirs yet.\n\nIt's never too late to g…",
#   datetime.datetime(2022, 2, 9, 10, 14, 43),
#   'Woking, UK'],
#  ['Bugspriet',
#   'RT @DrEricDing: 🧬Wow—REAWAKENING ancient virus remnants in human DNA—new study finds #SARSCoV2 “can induce (dormant) HERV-W ENV expression”…',
#   datetime.datetime(2022, 2, 9, 10, 14, 43),
#   'Anywhere'],
#  ['margaret_ruane',
#   'RT @runtokeepup: Gillian keegan taking a precautionary covid test before a meeting then going ahead with the meeting without waiting for th…',
#   datetime.datetime(2022, 2, 9, 10, 14, 43),
#   ''],
#  ['offrampracer',
#   'RT @LisaMarieBoothe: One silver lining with COVID is it has exposed the worthlessness of government and the majority of our leaders.',
#   datetime.datetime(2022, 2, 9, 10, 14, 43),
#   'Syracuse, NY'],
#  ['snlsambergs',
#   '3 days back at school and there’s already multiple covid cases. who would’ve thought?',
#   datetime.datetime(2022, 2, 9, 10, 14, 42),
#   'she/her | minor'],
#  ['tikitiktaalik',
#   'Boston University epidemiologist Dr. Eleanor Murray speaks on COVID-19 and endemicity https://t.co/Um74FI366m',
#   datetime.datetime(2022, 2, 9, 10, 14, 42),
#   'bir havlu bir rehbere bakar'],
#  ['mike69923907',
#   'RT @MarinaPurkiss: Beware the Tory groups\n\nThe ERG - that brought us Brexit\n\nThe Covid Recovery Group - that removed Covid health measures…',
#   datetime.datetime(2022, 2, 9, 10, 14, 42),
#   ''],
#  ['Dudshaw',
#   'RT @sajidjavid: Today we published our plan to tackle the Covid Backlog:\n\n👉🏽 deliver 9 million more tests, checks &amp; procedures by 2025\n\n👉🏽…',
#   datetime.datetime(2022, 2, 9, 10, 14, 42),
#   'Liverpool, England'],
#  ['j951',
#   'America 2022: Where Everyone Has Rights and No One Has Responsibilities https://t.co/aGnuCjiLhh',
#   datetime.datetime(2022, 2, 9, 10, 14, 42),
#   'So Cal'],
#  ['hendercum',
#   '@Dukefan11 @MLBONFOX Bruh you do you really think A) is an option? It’s just a press conference to air out what the… https://t.co/WgsWj3XUfl',
#   datetime.datetime(2022, 2, 9, 10, 14, 41),
#   'Manhattan, NY'],
#  ['Sly1036',
#   'RT @guardian: UK health minister apologises for continuing meeting after positive Covid test https://t.co/MUjtisT52d',
#   datetime.datetime(2022, 2, 9, 10, 14, 41),
#   'London'],
#  ['PaulCary',
#   'RT @Kit_Yates_Maths: The government\'s own coronavirus rules say an individual must isolate "straight away" if they record a positive latera…',
#   datetime.datetime(2022, 2, 9, 10, 14, 40),
#   ''],
#  ['melodytoone',
#   'RT @sharron_honey: https://t.co/Rj9AOkKLbS\nHealth minister Gillian Keegan apologises for continuing in-person meeting despite positive COVI…',
#   datetime.datetime(2022, 2, 9, 10, 14, 40),
#   ''],
#  ['hughes210',
#   'RT @TonyHinton2016: I have 3 questions:\n1. Are you against mandatory vaccines?\n2. Are you denying people can have better immunity after cov…',
#   datetime.datetime(2022, 2, 9, 10, 14, 40),
#   ''],
#  ['moggiemoy1',
#   'RT @BHheadlines: 🔥🔥𝗕𝗥𝗘𝗔𝗞𝗜𝗡𝗚⎜ Health Minister stayed at meeting with bereaved dads despite positive Covid test: Top Tory Gillian Keegan apol…',
#   datetime.datetime(2022, 2, 9, 10, 14, 40),
#   ''],
#  ['01ajr',
#   'RT @michaelsparling: These waiting times are not a Covid backlog. They are a Conservative backlog. Waiting times were rising prior to the p…',
#   datetime.datetime(2022, 2, 9, 10, 14, 40),
#   'Brighton, England'],
#  ['HWWarrington',
#   'RT @WarringtonCCG: Walk in COVID-19 vaccinations at Orford Jubilee Hub today, 9:00am - 2:00pm 💉\n\nPlease remember to wear a mask when enteri…',
#   datetime.datetime(2022, 2, 9, 10, 14, 40),
#   'Warrington, England'],
#  ['openyoureyes778',
#   'The Bible tells us the love of  money is the root of all evil. We can see it first hand where the hospitals were PA… https://t.co/4BCHrafgyv',
#   datetime.datetime(2022, 2, 9, 10, 14, 40),
#   'Pennsylvania,USA'],
#  ['MonkPahadi',
#   'RT @Pahaditribal: According to this bhakt whosoever died young during the mismanagement of covid crisis by Modi last year were all chandals…',
#   datetime.datetime(2022, 2, 9, 10, 14, 39),
#   ''],
#  ['anttweetsstuff',
#   'RT @corpsegiggle: "no one likes wearing masks but we still should because it keeps people safe"\n\nwrong! i\'ve always loved wearing masks! it…',
#   datetime.datetime(2022, 2, 9, 10, 14, 38),
#   'they/she/ae/gem'],
#  ['Ai_Diagnostics',
#   '‘Mission: Impossible 7’: How COVID-19 Blew Up the Budget of Tom Cruise’s Spy Sequel https://t.co/5VBL3CJmnM via @variety',
#   datetime.datetime(2022, 2, 9, 10, 14, 38),
#   'London, England'],
#  ['VanaAthanasiou',
#   "RT @WesElyMD: 1/🧵 #COVID Brain Changes Show Parallels w Alzheimer's Disease\n\xa0\nFindings may point to potential mechanism for #brainfog in pe…",
#   datetime.datetime(2022, 2, 9, 10, 14, 38),
#   'Ηγουμενίτσα'],
#  ['AlienDelegation',
#   "I'm now finishing an article about the poor communication crisis in Indonesia. I've written an argument about some… https://t.co/4hahJiMNfy",
#   datetime.datetime(2022, 2, 9, 10, 14, 38),
#   'Indonesia'],
#  ['cocoarrarra',
#   "RT @profmiketoole: My partner's father died today of *mild* Covid-19 in Cairo. Yes, he had type 2 diabetes but it was well controlled until…",
#   datetime.datetime(2022, 2, 9, 10, 14, 38),
#   ''],
#  ['DavidCHeads',
#   'RT @RCarlyleAuthor: In good news today, there is nobody in ICU with Covid in the whole of New Zealand. What an extraordinary achievement wh…',
#   datetime.datetime(2022, 2, 9, 10, 14, 37),
#   'Wellington, New Zealand'],
#  ['dactylion14',
#   "Army lieutenant colonel and professor of military studies who tweeted that 'it's time to resign' over COVID vaccine… https://t.co/OBONXsPlBK",
#   datetime.datetime(2022, 2, 9, 10, 14, 37),
#   ''],
#  ['AshleyKaiba',
#   'RT @thirstydriver: 🚨⚠️ BREAKING NEWS ⚠️🚨\n\nTHE ACADEMY TESTED POSITIVE FOR COVID ON ACCOUNT OF ABSOLUTELY NO FUCKING TASTE',
#   datetime.datetime(2022, 2, 9, 10, 14, 37),
#   'Florida, USA'],
#  ['silkiecarlo',
#   'It is a genuinely dangerous breach of the most basic public health requirement.\n\nFor those saying her action was ju… https://t.co/jml6vFy3XU',
#   datetime.datetime(2022, 2, 9, 10, 14, 36),
#   'London'],
#  ['melina_b_harris',
#   '@DavidLammy @MayorofLondon @RoryStewartUK not wearing masks is having a hugely detrimental effect on students - I a… https://t.co/x0j9HwHd3s',
#   datetime.datetime(2022, 2, 9, 10, 14, 36),
#   'London'],
#  ['WvSchaik',
#   '@MikeDeeeeeee The essay on COVID-19 has a distinct March/April 2020 vibe https://t.co/WjlyoP01gy',
#   datetime.datetime(2022, 2, 9, 10, 14, 36),
#   'Birmingham, England'],
#  ['ZerazumiA2',
#   'RT @elson_tong: CUHK shuts down all dormitories and evicts students by this weekend in light of COVID. While majority of students can retur…',
#   datetime.datetime(2022, 2, 9, 10, 14, 36),
#   ''],
#  ['gfilliman',
#   'RT @RepThomasMassie: What the?!\n“As COVID restrictions continue to decrease nationwide, increased access to commercial and government facil…',
#   datetime.datetime(2022, 2, 9, 10, 14, 36),
#   'Sun City, AZ'],
#  ['housedustmite',
#   "'COVID and the House Dust Mite, a dangerous and deadly combination?' Our new article raises a worrying topic and as… https://t.co/0uZhzqVGWV",
#   datetime.datetime(2022, 2, 9, 10, 14, 36),
#   'London, England  '],
#  ['oxyGINnT',
#   'RT @BernieSpofforth: Deaths in January were 5,000 lower than expected despite Covid case numbers. Total deaths from all causes are below th…',
#   datetime.datetime(2022, 2, 9, 10, 14, 35),
#   ''],
#  ['JglocoJay',
#   'Covid-19 cases, hospitalizations still too high to change mask guidance, CDC director says - CNN https://t.co/hBrwvCcdBE',
#   datetime.datetime(2022, 2, 9, 10, 14, 35),
#   ''],
#  ['DyorsMathew',
#   'RT @CellCellPress: Now online!  Respiratory mucosal delivery of next-generation COVID-19 vaccine provides robust protection against both an…',
#   datetime.datetime(2022, 2, 9, 10, 14, 34),
#   'Deutschland (Germany)'],
#  ['raffaelebrancat',
#   'RT @ShaunLintern: Your regular reminder that the NHS in England last met the target to see and treat 92% of patients within 18 weeks in Feb…',
#   datetime.datetime(2022, 2, 9, 10, 14, 34),
#   ''],
#  ['Shaunnotsharon',
#   'RT @dgurdasani1: There are currently no biomarkers that are used for diagnoses of long COVID, and even if there were, clinical history woul…',
#   datetime.datetime(2022, 2, 9, 10, 14, 34),
#   'Galera, España'],
#  ['SolGold936',
#   'RT @thevivafrei: Hate generates more clicks than accuracy @elonmusk. That, and the Canadian media is irreparably corrupted by government su…',
#   datetime.datetime(2022, 2, 9, 10, 14, 34),
#   ''],
#  ['QuantumWoofoo',
#   'RT @RayneNGrace: @dangjones @skfile99 Odd that Forbes posted this back in October of 2020 \n\nhttps://t.co/RedrnASzQK',
#   datetime.datetime(2022, 2, 9, 10, 14, 34),
#   'headless'],
#  ['M191376Jain',
#   'RT @BJP4India: This House praises the work put in by our healthcare and frontline workers during COVID. This will motivate them further.…',
#   datetime.datetime(2022, 2, 9, 10, 14, 33),
#   ''],
#  ['mamalla76375383',
#   'RT @bariweiss: Meet the moms who are are so fed up with our politics that they are actually running themselves. Or suing school boards. Or…',
#   datetime.datetime(2022, 2, 9, 10, 14, 33),
#   ''],
#  ['HealthyMeAtMSE',
#   'RT @JoanneColby1: Listening and responding to your concerns is as important as ever. The February #NHSPeoplePulseSurvey is open. Share your…',
#   datetime.datetime(2022, 2, 9, 10, 14, 33),
#   'Mid and South Essex'],
#  ['ffg_of',
#   '@lisabu1980 Upto 1k Apprenticeships were stopped last year, reason by unelected FFGG, Covid. Outdoors!\nIreland the… https://t.co/9iJgg1IRvX',
#   datetime.datetime(2022, 2, 9, 10, 14, 33),
#   ''],
#  ['Nanaman25449446',
#   'RT @BlakeMMurdoch: Do people not realize that if we invest in ventilation and filtration we are helping to mitigate not only COVID and all…',
#   datetime.datetime(2022, 2, 9, 10, 14, 33),
#   'Boogie Wonderland'],
#  ['c43166189',
#   'RT @AFP: Hong Kong has imposed its strictest social distancing measures yet as it struggles to maintain a "zero-Covid" policy amid an Omicr…',
#   datetime.datetime(2022, 2, 9, 10, 14, 33),
#   ''],
#  ['GMCVOJohn',
#   'RT @ProfTimBale: "Policies in Germany and Denmark placed care homes on a more or less equal footing with hospitals from early in the pandem…',
#   datetime.datetime(2022, 2, 9, 10, 14, 33),
#   'Whalley Range'],
#  ['TheLocalEurope',
#   'RT @TheLocalSpain: Spanish health authorities are considering reducing the days people infected with Covid-19 should spend in isolation fro…',
#   datetime.datetime(2022, 2, 9, 10, 14, 32),
#   'Europe'],
#  ['SomnathSil16',
#   'RT @himantabiswa: By developing &amp; manufacturing Covid vaccines, India proved its mettle to the world. It also shows that when Adarniya PM S…',
#   datetime.datetime(2022, 2, 9, 10, 14, 32),
#   'west bangal serampur....... ']]

# %%
tweet_text = pd.DataFrame(data=users_locs, 
                    columns=['user','tweet','time', "location"])
tweet_text
# Out:
#                 user  ...                      location
# 0            notshre  ...
# 1          WaddeyAli  ...                      Maldives
# 2         M_Haynes01  ...
# 3      sachinsaraf09  ...                         Earth
# 4       SparkleCat45  ...                 Hertfordshire
# ..               ...  ...                           ...
# 995  Nanaman25449446  ...             Boogie Wonderland
# 996        c43166189  ...
# 997        GMCVOJohn  ...                 Whalley Range
# 998   TheLocalEurope  ...                        Europe
# 999     SomnathSil16  ...  west bangal serampur.......
#
# [1000 rows x 4 columns]

# %%
tweet_text.time.max()
# Out:
# Timestamp('2022-02-09 10:17:51')

# %% [markdown]
# <h1>What is Colab?</h1>
#
# Colab, or ‘Colaboratory’, allows you to write and execute Python in your browser, with
# - Zero configuration required
# - Free access to GPUs
# - Easy sharing
#
# Whether you're a <strong>student</strong>, a <strong>data scientist</strong> or an <strong>AI researcher</strong>, Colab can make your work easier. Watch <a href="https://www.youtube.com/watch?v=inN8seMm7UI">Introduction to Colab</a> to find out more, or just get started below!

# %% [markdown]
# ## <strong>Getting started</strong>
#
# The document that you are reading is not a static web page, but an interactive environment called a <strong>Colab notebook</strong> that lets you write and execute code.
#
# For example, here is a <strong>code cell</strong> with a short Python script that computes a value, stores it in a variable and prints the result:

# %%
seconds_in_a_day = 24 * 60 * 60
seconds_in_a_day
# Out:
# 86400

# %% [markdown]
# To execute the code in the above cell, select it with a click and then either press the play button to the left of the code, or use the keyboard shortcut 'Command/Ctrl+Enter'. To edit the code, just click the cell and start editing.
#
# Variables that you define in one cell can later be used in other cells:

# %%
seconds_in_a_week = 7 * seconds_in_a_day
seconds_in_a_week
# Out:
# 604800

# %% [markdown]
# Colab notebooks allow you to combine <strong>executable code</strong> and <strong>rich text</strong> in a single document, along with <strong>images</strong>, <strong>HTML</strong>, <strong>LaTeX</strong> and more. When you create your own Colab notebooks, they are stored in your Google Drive account. You can easily share your Colab notebooks with co-workers or friends, allowing them to comment on your notebooks or even edit them. To find out more, see <a href="/notebooks/basic_features_overview.ipynb">Overview of Colab</a>. To create a new Colab notebook you can use the File menu above, or use the following link: <a href="http://colab.research.google.com#create=true">Create a new Colab notebook</a>.
#
# Colab notebooks are Jupyter notebooks that are hosted by Colab. To find out more about the Jupyter project, see <a href="https://www.jupyter.org">jupyter.org</a>.

# %% [markdown]
# ## Data science
#
# With Colab you can harness the full power of popular Python libraries to analyse and visualise data. The code cell below uses <strong>numpy</strong> to generate some random data, and uses <strong>matplotlib</strong> to visualise it. To edit the code, just click the cell and start editing.

# %%
import numpy as np
from matplotlib import pyplot as plt

ys = 200 + np.random.randn(100)
x = [x for x in range(len(ys))]

plt.plot(x, ys, '-')
plt.fill_between(x, ys, 195, where=(ys > 195), facecolor='g', alpha=0.6)

plt.title("Sample Visualization")
plt.show()

# %% [markdown]
# You can import your own data into Colab notebooks from your Google Drive account, including from spreadsheets, as well as from GitHub and many other sources. To find out more about importing data, and how Colab can be used for data science, see the links below under <a href="#working-with-data">Working with data</a>.

# %% [markdown]
# ## Machine learning
#
# With Colab you can import an image dataset, train an image classifier on it, and evaluate the model, all in just <a href="https://colab.research.google.com/github/tensorflow/docs/blob/master/site/en/tutorials/quickstart/beginner.ipynb">a few lines of code</a>. Colab notebooks execute code on Google's cloud servers, meaning you can leverage the power of Google hardware, including <a href="#using-accelerated-hardware">GPUs and TPUs</a>, regardless of the power of your machine. All you need is a browser.

# %% [markdown]
# Colab is used extensively in the machine learning community with applications including:
# - Getting started with TensorFlow
# - Developing and training neural networks
# - Experimenting with TPUs
# - Disseminating AI research
# - Creating tutorials
#
# To see sample Colab notebooks that demonstrate machine learning applications, see the <a href="#machine-learning-examples">machine learning examples</a> below.

# %% [markdown]
# ## More resources
#
# ### Working with notebooks in Colab
# - [Overview of Colaboratory](/notebooks/basic_features_overview.ipynb)
# - [Guide to markdown](/notebooks/markdown_guide.ipynb)
# - [Importing libraries and installing dependencies](/notebooks/snippets/importing_libraries.ipynb)
# - [Saving and loading notebooks in GitHub](https://colab.research.google.com/github/googlecolab/colabtools/blob/main/notebooks/colab-github-demo.ipynb)
# - [Interactive forms](/notebooks/forms.ipynb)
# - [Interactive widgets](/notebooks/widgets.ipynb)
# - <img src="/img/new.png" height="20px" align="left" hspace="4px" alt="New"></img>
#  [TensorFlow 2 in Colab](/notebooks/tensorflow_version.ipynb)
#
# <a name="working-with-data"></a>
# ### Working with data
# - [Loading data: Drive, Sheets and Google Cloud Storage](/notebooks/io.ipynb)
# - [Charts: visualising data](/notebooks/charts.ipynb)
# - [Getting started with BigQuery](/notebooks/bigquery.ipynb)
#
# ### Machine learning crash course
# These are a few of the notebooks from Google's online machine learning course. See the <a href="https://developers.google.com/machine-learning/crash-course/">full course website</a> for more.
# - [Intro to Pandas DataFrame](https://colab.research.google.com/github/google/eng-edu/blob/main/ml/cc/exercises/pandas_dataframe_ultraquick_tutorial.ipynb)
# - [Linear regression with tf.keras using synthetic data](https://colab.research.google.com/github/google/eng-edu/blob/main/ml/cc/exercises/linear_regression_with_synthetic_data.ipynb)
#
#
# <a name="using-accelerated-hardware"></a>
# ### Using accelerated hardware
# - [TensorFlow with GPUs](/notebooks/gpu.ipynb)
# - [TensorFlow with TPUs](/notebooks/tpu.ipynb)

# %% [markdown]
# <a name="machine-learning-examples"></a>
#
# ### Featured examples
#
# - <a href="https://colab.research.google.com/github/NVIDIA/NeMo/blob/stable/tutorials/VoiceSwapSample.ipynb">NeMo voice swap</a>: Use Nvidia NeMo conversational AI toolkit to swap a voice in an audio fragment with a computer-generated one.
#
# - <a href="https://tensorflow.org/hub/tutorials/tf2_image_retraining">Retraining an Image Classifier</a>: Build a Keras model on top of a pre-trained image classifier to distinguish flowers.
# - <a href="https://tensorflow.org/hub/tutorials/tf2_text_classification">Text Classification</a>: Classify IMDB film reviews as either <em>positive</em> or <em>negative</em>.
# - <a href="https://tensorflow.org/hub/tutorials/tf2_arbitrary_image_stylization">Style Transfer</a>: Use deep learning to transfer style between images.
# - <a href="https://tensorflow.org/hub/tutorials/retrieval_with_tf_hub_universal_encoder_qa">Multilingual Universal Sentence Encoder Q&amp;A</a>: Use a machine-learning model to answer questions from the SQuAD dataset.
# - <a href="https://tensorflow.org/hub/tutorials/tweening_conv3d">Video Interpolation</a>: Predict what happened in a video between the first and the last frame.
